# %%
import json

# %%
burb_dict = json.load(open('data/burberry.json'))

# %%
burb_dict
# Out:
# {'account_name': 'burberry',
#  'follower_count': 11161322,
#  'following_count': 377,
#  'instagram_url': 'https://instagram.com/burberry/',
#  'post_count': 3786,
#  'post_urls_list': ['https://www.instagram.com/p/BgysBY8gWE5/?taken-by=burberry',
#   'https://www.instagram.com/p/BgrGPmrgkta/?taken-by=burberry',
#   'https://www.instagram.com/p/Bgq0WYKgK6l/?taken-by=burberry',
#   'https://www.instagram.com/p/BgqeGvCAEJl/?taken-by=burberry',
#   'https://www.instagram.com/p/BgojPC2ALXB/?taken-by=burberry',
#   'https://www.instagram.com/p/BgoPlRFHhN0/?taken-by=burberry',
#   'https://www.instagram.com/p/BgoBR0JnZfT/?taken-by=burberry',
#   'https://www.instagram.com/p/BgnxwMmHEDS/?taken-by=burberry',
#   'https://www.instagram.com/p/BgmAw4zH1Ap/?taken-by=burberry',
#   'https://www.instagram.com/p/Bglu1OPnU3x/?taken-by=burberry',
#   'https://www.instagram.com/p/BglkM85nHjP/?taken-by=burberry',
#   'https://www.instagram.com/p/BgjXNRmHOrB/?taken-by=burberry',
# ...

# %%
len(burb_dict['post_urls_list'])
# Out:
# 3786

# %%
test_url = 'https://www.instagram.com/p/BgysBY8gWE5/?taken-by=burberry'
